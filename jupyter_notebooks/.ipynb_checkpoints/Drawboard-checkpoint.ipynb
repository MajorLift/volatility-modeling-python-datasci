# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid")

import statsmodels.api as sm
import scipy.stats as scs

import warnings
warnings.filterwarnings('ignore')

# %%
# Scrape OHLC data from Yahoo Finance API for 
# S&P500 Index, CBE VIX Index, SSE Composite Index, CNY/USD rates
# throughout the time period of 2008-01-01 to 2020-04-30.

# import yfinance as yf

# raw = yf.download(
#         tickers = "^GSPC ^VIX 000001.SS CNYUSD=X",
#         start = "2007-01-01",
#         end = "2020-05-01",
#         interval = "1d",
#         group_by = "ticker"
#         )
# raw.to_csv("raw.csv", header=True)

# %%
df = pd.read_csv("raw.csv")

# Data Cleanup and Preprocessing
# Leave only dates and close values.
df = df.iloc[3:, [0] + [6*i + 4 for i in range(4)]]
date = pd.to_datetime(df.iloc[:,0]).rename("date", inplace=True)
# initialize new dataframe
df = pd.DataFrame({"date": date,
                    "SPX": df["^GSPC.3"],
                    "VIX": df["^VIX.3"],
                    "SSE": df["000001.SS.3"],
                    "CNY": df["CNYUSD=X.3"]})
df.set_index(df["date"], drop=True, inplace=True)
df = df.dropna(axis=0, how="any")

# Manual correction of error entry 
# for this particular date in Yahoo Finance data.
# Replaced with data from investing.com
df.loc["2011-07-18", "CNY"] = 0.1546

# preserve date range Series for log-return dataframe.
date = df["date"]
del df["date"]

for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# generate graphs
sns.relplot(kind="line", data=df[["SPX","SSE"]])
sns.relplot(kind="line", data=df["VIX"])
sns.relplot(kind="line", data=df["CNY"])

# %%
# Convert daily close quotes to one-day-ahead log returns in percentages + generate graphs
def getLogReturns(quotes):
    return [100 * np.log(quotes[i] / quotes[i-1])
           for i in range(1, len(quotes))]

df_lret = pd.DataFrame(columns=df.columns, index=date[1:])
for col in df_lret.columns:
    if col == "VIX":
        df_lret[col] = df[col][1:]
    else:
        df_lret[col] = getLogReturns(df[col].tolist())
    sns.relplot(kind="line", data=df_lret[col])

# %%
# Separate Dataframes for the Great Recession and Coronavirus Recession
# defined respectively as Dec 2007 ~ Jun 2009 and Dec 2019 ~

# Global Date Variables
ALL_START = "2007-01-01"
ALL_END = "2020-05-01"
TRAIN_END = "2018-12-31"
FORECAST_START = "2019-01-01"
GR_START = "2007-12-01"
GR_END = "2009-07-01"
COVID_START = "2019-12-01"
COVID_END = "2020-05-01"

COLS_EXCL_VIX = ("SPX", "SSE", "CNY")

GRdf = df[GR_START:GR_END].copy()
GRdf_lret = df_lret[GR_START:GR_END].copy()

CRdf = df[COVID_START:].copy()
CRdf_lret = df_lret[COVID_START:].copy()

resultsdb = {"ALL": ["Full Timeframe", df_lret],
             "CR": ["COVID-19 Recession", CRdf_lret]}

for data in GRdf, CRdf:
    sns.relplot(kind="line", data=data[["SPX","SSE"]])
    sns.relplot(kind="line", data=data["VIX"])
    sns.relplot(kind="line", data=data["CNY"])

# %%
# Diagnostic Tests

# Augmented Dickey-Fuller: Stationarity (Unit Root)
def adf(timeseries, title, cutoff=0.01):
    result = False
    
    print('Results of Dickey-Fuller Test for: ' + title)
    dftest = sm.tsa.stattools.adfuller(timeseries, autolag='AIC')
    
    pvalue = dftest[1]
    if pvalue < cutoff:
        print('p-value = %.6f. The series is likely stationary.' % pvalue)
        result = True
    else:
        print('p-value = %.6f. The series is likely non-stationary.' % pvalue)

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    print()
    
    return result

for v in resultsdb.values():
    data = v[1]
    print(v[0] + ": \n")
    for col in data.columns:
        title = " - ".join((v[0], col))
        adf(data[col], title)
        print()
# Out:
# Full Timeframe:
#
# Results of Dickey-Fuller Test for: Full Timeframe - SPX
# p-value = 0.000000. The series is likely stationary.
# Test Statistic                -1.003840e+01
# p-value                        1.519034e-17
# #Lags Used                     2.900000e+01
# Number of Observations Used    3.097000e+03
# Critical Value (1%)           -3.432463e+00
# Critical Value (5%)           -2.862474e+00
# Critical Value (10%)          -2.567267e+00
# dtype: float64
#
#
# Results of Dickey-Fuller Test for: Full Timeframe - VIX
# p-value = 0.000136. The series is likely stationary.
# Test Statistic                   -4.588621
# p-value                           0.000136
# #Lags Used                       12.000000
# Number of Observations Used    3114.000000
# Critical Value (1%)              -3.432452
# Critical Value (5%)              -2.862469
# Critical Value (10%)             -2.567264
# dtype: float64
#
#
# Results of Dickey-Fuller Test for: Full Timeframe - SSE
# p-value = 0.000000. The series is likely stationary.
# Test Statistic                  -20.690108
# p-value                           0.000000
# #Lags Used                        6.000000
# Number of Observations Used    3120.000000
# Critical Value (1%)              -3.432448
# Critical Value (5%)              -2.862467
# Critical Value (10%)             -2.567263
# dtype: float64
#
#
# Results of Dickey-Fuller Test for: Full Timeframe - CNY
# p-value = 0.000000. The series is likely stationary.
# Test Statistic                -8.693642e+00
# p-value                        3.978517e-14
# #Lags Used                     2.400000e+01
# Number of Observations Used    3.102000e+03
# Critical Value (1%)           -3.432460e+00
# Critical Value (5%)           -2.862472e+00
# Critical Value (10%)          -2.567266e+00
# dtype: float64
#
#
# COVID-19 Recession:
#
# Results of Dickey-Fuller Test for: COVID-19 Recession - SPX
# p-value = 0.090549. The series is likely non-stationary.
# Test Statistic                 -2.611965
# p-value                         0.090549
# #Lags Used                      6.000000
# Number of Observations Used    89.000000
# Critical Value (1%)            -3.506057
# Critical Value (5%)            -2.894607
# Critical Value (10%)           -2.584410
# dtype: float64
#
#
# Results of Dickey-Fuller Test for: COVID-19 Recession - VIX
# p-value = 0.536593. The series is likely non-stationary.
# Test Statistic                 -1.493765
# p-value                         0.536593
# #Lags Used                      3.000000
# Number of Observations Used    92.000000
# Critical Value (1%)            -3.503515
# Critical Value (5%)            -2.893508
# Critical Value (10%)           -2.583824
# dtype: float64
#
#
# Results of Dickey-Fuller Test for: COVID-19 Recession - SSE
# p-value = 0.000000. The series is likely stationary.
# Test Statistic                -9.882943e+00
# p-value                        3.728173e-17
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.500000e+01
# Critical Value (1%)           -3.501137e+00
# Critical Value (5%)           -2.892480e+00
# Critical Value (10%)          -2.583275e+00
# dtype: float64
#
#
# Results of Dickey-Fuller Test for: COVID-19 Recession - CNY
# p-value = 0.000000. The series is likely stationary.
# Test Statistic                -1.079802e+01
# p-value                        2.051714e-19
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.500000e+01
# Critical Value (1%)           -3.501137e+00
# Critical Value (5%)           -2.892480e+00
# Critical Value (10%)          -2.583275e+00
# dtype: float64

# %%
# Apply second-order differencing to non-stationary dataset
def getSecondOrderLogReturns(quotes):
    return [100 * np.log((quotes[i] / quotes[i-1]) / (quotes[i-1] / quotes[i-2]))
           for i in range(2, len(quotes))]

#df.loc["2019-11-25":"2019-12-01"].head()
COVID_df = resultsdb["CR"][1]
COVID_df["SPX"] = getSecondOrderLogReturns(df.loc["2019-11-27":,"SPX"].tolist())
adf(COVID_df["SPX"], "COVID-SPX")
# Out:
# Results of Dickey-Fuller Test for: COVID-SPX
# p-value = 0.000000. The series is likely stationary.
# Test Statistic                -6.011769e+00
# p-value                        1.567317e-07
# #Lags Used                     7.000000e+00
# Number of Observations Used    8.800000e+01
# Critical Value (1%)           -3.506944e+00
# Critical Value (5%)           -2.894990e+00
# Critical Value (10%)          -2.584615e+00
# dtype: float64
# True

# %%
# Find ARIMA(p,1,q) models for log-return series that minimize AIC
# where p,q <= 5 and excluding ARIMA(0,1,0)
import statsmodels.tsa.arima_model as arima

def fit_ARIMA(timeseries, d=1, verbose=False):
    min_aic = 2 ** 32
    pdq = (6,d,6)
    results = []
    if verbose:
        print("Approximating model fitting to save time...")
    for p in range(6):
        for q in range(6):
            if p > 0 or q > 0:
                try:
                    model = arima.ARIMA(timeseries, (p,d,q))
                    fitted = model.fit(transparams=False,
                                       method="css",
                                       trend="nc",
                                       maxiter=50)
                    aic = arima.ARIMAResults(model, fitted.params).aic
                    if verbose:
                        print("ARIMA(" + ",".join((str(p),str(d),str(q))) + ") - AIC: " + str(aic))                    
                    results.append([aic, (p,d,q)])
                except ValueError:
                    continue

    results = sorted(results, key=lambda x: x[0])
    if verbose:
        print("Refitting best model without approximation...")
    for result in results:
        try:
            p,d,q = result[1]
            model = arima.ARIMA(timeseries, (p,d,q))
            fitted = model.fit(transparams=False)
            residuals = arima.ARIMAResults(model, fitted.params).resid
            aic = arima.ARIMAResults(model, fitted.params).aic
            print("ARIMA(" + ",".join((str(p),str(d),str(q))) + ") - AIC: " + str(aic))
            return ((p,d,q), model, fitted, residuals)
        except ValueError:
            continue

# %%
for v in resultsdb.values():
    data = v[1]
    if len(v) == 2:
        v.append({})
    ARIMA = v[2]
    for col in COLS_EXCL_VIX:
        title = v[0] + " - " + str(col)
        print(title)
        if v[0] == "COVID-19 Recession" and col == "SPX":
            ARIMA[col] = fit_ARIMA(data[col], d=2, verbose=True)
        else: 
            ARIMA[col] = fit_ARIMA(data[col], verbose=True)
        p,d,q = ARIMA[col][0]
        print(title)
        print("Best Model: ARIMA(" + ",".join((str(p),str(d),str(q))) + ")\n")
    
    summary = arima.ARIMAResults(ARIMA[col][1], ARIMA[col][2].params).summary()
    print(summary)
# Out:
# Full Timeframe - SPX
# Approximating model fitting to save time...
# ARIMA(0,1,1) - AIC: 11749.930355829167
# ARIMA(0,1,2) - AIC: 11567.663751077278
# ARIMA(0,1,3) - AIC: 11514.839055718472
# ARIMA(0,1,4) - AIC: 11363.052595944382
# ARIMA(0,1,5) - AIC: 11273.546717075522
# ARIMA(1,1,0) - AIC: 12173.969068524175
# ARIMA(1,1,1) - AIC: 10845.549752623167
# ARIMA(1,1,2) - AIC: 10778.651008568477
# ARIMA(1,1,3) - AIC: 10840.722701216633
# ARIMA(1,1,4) - AIC: 10770.844434678547
# ARIMA(2,1,0) - AIC: 11674.187177830709
# ARIMA(2,1,1) - AIC: 10947.939247631915
# ARIMA(2,1,2) - AIC: 10863.000051320236
# ARIMA(2,1,3) - AIC: 10790.875458941477
# ARIMA(2,1,4) - AIC: 10803.937166813052
# ARIMA(2,1,5) - AIC: 10777.28216313549
# ARIMA(3,1,0) - AIC: 11483.930890167936
# ARIMA(3,1,1) - AIC: 10938.176087141996
# ARIMA(3,1,2) - AIC: 10853.182544304942
# ARIMA(3,1,3) - AIC: 10812.94749739814
# ARIMA(3,1,4) - AIC: 10786.970502321403
# ARIMA(3,1,5) - AIC: 10799.970704368643
# ARIMA(4,1,0) - AIC: 11377.680353976686
# ARIMA(4,1,1) - AIC: 10951.0800046722
# ARIMA(4,1,2) - AIC: 10839.864373949174
# ARIMA(4,1,3) - AIC: 10797.28020079763
# ARIMA(4,1,4) - AIC: 10800.80808880263
# ARIMA(4,1,5) - AIC: 10790.18290991058
# ARIMA(5,1,0) - AIC: 11295.17030490211
# ARIMA(5,1,1) - AIC: 10959.954669199215
# ARIMA(5,1,2) - AIC: 10852.319289718107
# ARIMA(5,1,3) - AIC: 10785.7652638736
# ARIMA(5,1,4) - AIC: 10783.00935155667
# ARIMA(5,1,5) - AIC: 10783.660728149518
# Refitting best model without approximation...
# ARIMA(1,1,4) - AIC: 10758.198192546315
# Full Timeframe - SPX
# Best Model: ARIMA(1,1,4)
#
# Full Timeframe - SSE
# Approximating model fitting to save time...
# ARIMA(0,1,1) - AIC: 13048.354529023858
# ARIMA(0,1,2) - AIC: 12854.293516758573
# ARIMA(0,1,3) - AIC: 12729.897795401514
# ARIMA(0,1,4) - AIC: 12792.105897801455
# ARIMA(0,1,5) - AIC: 12598.185720794956
# ARIMA(1,1,0) - AIC: 13425.710583403781
# ARIMA(1,1,1) - AIC: 12240.184921713499
# ARIMA(1,1,2) - AIC: 12217.496565325078
# ARIMA(1,1,3) - AIC: 12243.725013263349
# ARIMA(1,1,4) - AIC: 12276.001589235706
# ARIMA(1,1,5) - AIC: 12167.982435061538
# ARIMA(2,1,0) - AIC: 13005.189035617846
# ARIMA(2,1,1) - AIC: 12291.68646729945
# ARIMA(2,1,2) - AIC: 12269.438135623755
# ARIMA(2,1,3) - AIC: 12235.70168514302
# ARIMA(2,1,4) - AIC: 12259.868352700958
# ARIMA(2,1,5) - AIC: 12191.973357498264
# ARIMA(3,1,0) - AIC: 12741.968491802483
# ARIMA(3,1,1) - AIC: 12322.616785316886
# ARIMA(3,1,2) - AIC: 12289.886629863337
# ARIMA(3,1,3) - AIC: 12258.794592679495
# ARIMA(3,1,4) - AIC: 12226.56775958633
# ARIMA(3,1,5) - AIC: 12192.37688068479
# ARIMA(4,1,0) - AIC: 12679.850141504729
# ARIMA(4,1,1) - AIC: 12196.580403307791
# ARIMA(4,1,2) - AIC: 12196.995690643858
# ARIMA(4,1,3) - AIC: 12175.114551467388
# ARIMA(4,1,4) - AIC: 12186.594367798509
# ARIMA(4,1,5) - AIC: 12185.60211431534
# ARIMA(5,1,0) - AIC: 12611.258919001144
# ARIMA(5,1,1) - AIC: 12249.232927276098
# ARIMA(5,1,2) - AIC: 12218.510698655042
# ARIMA(5,1,3) - AIC: 12174.974489862365
# ARIMA(5,1,4) - AIC: 12174.988293055208
# ARIMA(5,1,5) - AIC: 12172.229252496123
# Refitting best model without approximation...
# ARIMA(1,1,5) - AIC: 12169.557534309832
# Full Timeframe - SSE
# Best Model: ARIMA(1,1,5)
#
# Full Timeframe - CNY
# Approximating model fitting to save time...
# ARIMA(0,1,1) - AIC: -29.13573675333828
# ARIMA(0,1,2) - AIC: -206.52548076525773
# ARIMA(0,1,3) - AIC: -371.4381182408606
# ARIMA(0,1,4) - AIC: -499.5858414269346
# ARIMA(0,1,5) - AIC: -484.5723642095395
# ARIMA(1,1,0) - AIC: 410.7425329222119
# ARIMA(1,1,1) - AIC: -993.2026469596458
# ARIMA(1,1,3) - AIC: -984.1199967204666
# ARIMA(1,1,4) - AIC: -978.2931294556129
# ARIMA(1,1,5) - AIC: -964.0756003582028
# ARIMA(2,1,0) - AIC: -53.85230670134297
# ARIMA(2,1,1) - AIC: -963.478153585922
# ARIMA(2,1,2) - AIC: -990.851344364708
# ARIMA(2,1,3) - AIC: -990.2270026319829
# ARIMA(2,1,4) - AIC: -976.6396762590339
# ARIMA(2,1,5) - AIC: -961.8864251986461
# ARIMA(3,1,0) - AIC: -301.0374075420541
# ARIMA(3,1,1) - AIC: -940.1179932359623
# ARIMA(3,1,2) - AIC: -971.9734353448985
# ARIMA(3,1,3) - AIC: -974.7453831649482
# ARIMA(3,1,4) - AIC: -977.2645130643805
# ARIMA(3,1,5) - AIC: -970.1053513393567
# ARIMA(4,1,0) - AIC: -489.5427088080846
# ARIMA(4,1,1) - AIC: -886.445363256255
# ARIMA(4,1,2) - AIC: -947.5900990771224
# ARIMA(4,1,3) - AIC: -955.2473210088333
# ARIMA(4,1,4) - AIC: -976.4885335347017
# ARIMA(4,1,5) - AIC: -979.5448719116303
# ARIMA(5,1,0) - AIC: -552.3145348592652
# ARIMA(5,1,1) - AIC: -945.9725836487696
# ARIMA(5,1,2) - AIC: -972.2018515217806
# ARIMA(5,1,3) - AIC: -968.6237081054169
# ARIMA(5,1,4) - AIC: -977.610171230469
# ARIMA(5,1,5) - AIC: -976.2338505088715
# Refitting best model without approximation...
# ARIMA(1,1,1) - AIC: -1003.5401487642739
# Full Timeframe - CNY
# Best Model: ARIMA(1,1,1)
#
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                  D.CNY   No. Observations:                 3126
# Model:                    ARIMA(1, 1)   Log Likelihood                 505.770
# Method:                       css-mle   S.D. of innovations              0.206
# Date:                Sat, 23 May 2020   AIC                          -1003.540
# Time:                        05:33:02   BIC                           -979.350
# Sample:                             0   HQIC                          -994.857
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.374e-05   3.63e-06     -3.783      0.000   -2.09e-05   -6.62e-06
# ar.L1.D.CNY    -0.1216      0.018     -6.851      0.000      -0.156      -0.087
# ma.L1.D.CNY    -1.0000      0.001   -975.481      0.000      -1.002      -0.998
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -8.2227           +0.0000j            8.2227            0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# COVID-19 Recession - SPX
# Approximating model fitting to save time...
# ARIMA(0,2,1) - AIC: 702.2275385887779
# ARIMA(1,2,0) - AIC: 698.3855337436279
# ARIMA(2,2,0) - AIC: 608.8200158343711
# ARIMA(2,2,3) - AIC: 495.86513896282014
# ARIMA(3,2,0) - AIC: 582.2799030010531
# ARIMA(4,2,1) - AIC: 505.387192273352
# Refitting best model without approximation...
# ARIMA(2,2,3) - AIC: 509.51875670318844
# COVID-19 Recession - SPX
# Best Model: ARIMA(2,2,3)
#
# COVID-19 Recession - SSE
# Approximating model fitting to save time...
# ARIMA(0,1,1) - AIC: 351.20128860037755
# ARIMA(0,1,2) - AIC: 353.17923858313753
# ARIMA(0,1,3) - AIC: 354.75355390468417
# ARIMA(0,1,4) - AIC: 356.5167803806821
# ARIMA(0,1,5) - AIC: 350.1952566686148
# ARIMA(1,1,0) - AIC: 383.55488038383845
# ARIMA(1,1,1) - AIC: 352.0694241935647
# ARIMA(1,1,2) - AIC: 346.12846447683467
# ARIMA(1,1,3) - AIC: 348.24209735649737
# ARIMA(2,1,0) - AIC: 370.063646528214
# ARIMA(2,1,1) - AIC: 350.4994830615223
# ARIMA(3,1,0) - AIC: 367.75832433888826
# ARIMA(3,1,1) - AIC: 352.6320239249319
# ARIMA(3,1,2) - AIC: 350.8264568135313
# ARIMA(4,1,0) - AIC: 361.7281812927287
# ARIMA(4,1,1) - AIC: 348.48309641874084
# ARIMA(4,1,2) - AIC: 334.6230784034026
# ARIMA(5,1,0) - AIC: 355.79532895220757
# ARIMA(5,1,1) - AIC: 333.88749654055965
# ARIMA(5,1,2) - AIC: 334.72764073255837
# ARIMA(5,1,3) - AIC: 335.8066613798002
# Refitting best model without approximation...
# ARIMA(5,1,1) - AIC: 364.6105897315973
# COVID-19 Recession - SSE
# Best Model: ARIMA(5,1,1)
#
# COVID-19 Recession - CNY
# Approximating model fitting to save time...
# ARIMA(0,1,1) - AIC: 61.8423647479326
# ARIMA(0,1,2) - AIC: 62.805232421211414
# ARIMA(0,1,3) - AIC: 64.79015051315758
# ARIMA(0,1,4) - AIC: 66.78886798354763
# ARIMA(0,1,5) - AIC: 66.52381230483124
# ARIMA(1,1,0) - AIC: 100.95309994629721
# ARIMA(1,1,1) - AIC: 65.04968116043507
# ARIMA(1,1,2) - AIC: 64.93717661439098
# ARIMA(1,1,3) - AIC: 56.82570193397082
# ARIMA(1,1,4) - AIC: 68.79203696762332
# ARIMA(2,1,0) - AIC: 91.01400085161377
# ARIMA(2,1,1) - AIC: 75.17600539275571
# ARIMA(2,1,2) - AIC: 72.7061498780293
# ARIMA(2,1,3) - AIC: 40.23815710355153
# ARIMA(2,1,4) - AIC: 44.67707628881007
# ARIMA(2,1,5) - AIC: 53.39382277818554
# ARIMA(3,1,0) - AIC: 80.27619872803231
# ARIMA(3,1,1) - AIC: 68.00263286776112
# ARIMA(3,1,2) - AIC: 55.017790629922324
# ARIMA(3,1,3) - AIC: 45.02582134715941
# ARIMA(3,1,4) - AIC: 58.67187880834588
# ARIMA(4,1,0) - AIC: 79.20229102336008
# ARIMA(4,1,1) - AIC: 54.11074220677971
# ARIMA(4,1,2) - AIC: 56.83777111930435
# ARIMA(4,1,3) - AIC: 59.46247332556818
# ARIMA(4,1,4) - AIC: 60.734089714793164
# ARIMA(5,1,0) - AIC: 80.55854986870862
# ARIMA(5,1,1) - AIC: 72.3839406920231
# ARIMA(5,1,2) - AIC: 67.69047302121399
# ARIMA(5,1,4) - AIC: 60.76539446743671
# Refitting best model without approximation...
# ARIMA(2,1,3) - AIC: 72.41321131046692
# COVID-19 Recession - CNY
# Best Model: ARIMA(2,1,3)
#
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                  D.CNY   No. Observations:                   95
# Model:                    ARIMA(2, 3)   Log Likelihood                 -29.207
# Method:                       css-mle   S.D. of innovations              0.318
# Date:                Sat, 23 May 2020   AIC                             72.413
# Time:                        05:33:24   BIC                             90.290
# Sample:                             0   HQIC                            79.637
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -0.0008      0.001     -0.686      0.493      -0.003       0.002
# ar.L1.D.CNY    -0.6477      0.147     -4.400      0.000      -0.936      -0.359
# ar.L2.D.CNY    -0.9421      0.054    -17.306      0.000      -1.049      -0.835
# ma.L1.D.CNY    -0.3082      0.122     -2.520      0.012      -0.548      -0.068
# ma.L2.D.CNY     0.3082      0.126      2.443      0.015       0.061       0.555
# ma.L3.D.CNY    -1.0000      0.073    -13.661      0.000      -1.143      -0.857
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.3437           -0.9712j            1.0303           -0.3041
# AR.2           -0.3437           +0.9712j            1.0303            0.3041
# MA.1            1.0000           -0.0000j            1.0000           -0.0000
# MA.2           -0.3459           -0.9383j            1.0000           -0.3062
# MA.3           -0.3459           +0.9383j            1.0000            0.3062
# -----------------------------------------------------------------------------

# %%
# Quickly populate resultsdb with known values from above cell

# def fit_arima(timeseries, pdq_tuple):
#     model = arima.ARIMA(timeseries, pdq_tuple)
#     fitted = model.fit(transparams=False)
#     residuals = arima.ARIMAResults(model, fitted.params).resid
#     return (pdq_tuple, model, fitted, residuals)

# pdq = [[(1,1,4),(1,1,5),(1,1,1),
#         (4,2,1),(5,1,1),(2,1,3)]]

# for i, v in enumerate(resultsdb.values()):
#     data = v[1]
#     if (len(v) == 2):
#         v.append({})
#     ARIMA = v[2]
#     for j, col in enumerate(COLS_EXCL_VIX):
#         if v[2] == {}:
#             ARIMA[col] = fit_arima(data[col], pdq[i][j])
#         summary = arima.ARIMAResults(ARIMA[col][1], ARIMA[col][2].params).summary()
#         print("\n" + v[0] + " - " + col + ":")
#         print(summary)

# %%
# Jarque-Bera Test of Normality in the ARIMA-fitted residuals + QQ plots
from statsmodels.graphics.gofplots import qqplot

for v in resultsdb.values():
    data = v[1]
    for col in COLS_EXCL_VIX:
        title = v[0] + " - " + col
        res = v[2][col][3]
        result = sm.stats.stattools.jarque_bera(res)
        print(title)
        print("JB statistic: " + str(result[0]) + ", p-value: " + str(result[1])
             + ", Skewness: " + str(result[2]) + ", Kurtosis: " + str(result[3]))
        if result[1] < 0.01:
            print(col + " is within the threshold for normal distribution.")
        else:
            print(col + " is non-normal.")
        print(qqplot(data[col]))
# Out:
# Full Timeframe - SPX
# JB statistic: 26321.99838872674, p-value: 0.0, Skewness: -0.7784613884980597, Kurtosis: 17.13026082004475
# SPX is within the threshold for normal distribution.
# Figure(432x288)
# Full Timeframe - SSE
# JB statistic: 3900.9178348127566, p-value: 0.0, Skewness: -0.670277179851941, Kurtosis: 8.305881562115317
# SSE is within the threshold for normal distribution.
# Figure(432x288)
# Full Timeframe - CNY
# JB statistic: 14418.441043841709, p-value: 0.0, Skewness: -0.2366809297674625, Kurtosis: 13.510667549752903
# CNY is within the threshold for normal distribution.
# Figure(432x288)
# COVID-19 Recession - SPX
# JB statistic: 33.02975607260703, p-value: 6.72480351290286e-08, Skewness: 0.6089636467507317, Kurtosis: 5.636243979181655
# SPX is within the threshold for normal distribution.
# Figure(432x288)
# COVID-19 Recession - SSE
# JB statistic: 280.14620535656053, p-value: 1.4690089567623833e-61, Skewness: -1.766356498578403, Kurtosis: 10.635032224886872
# SSE is within the threshold for normal distribution.
# Figure(432x288)
# COVID-19 Recession - CNY
# JB statistic: 19.10228166462337, p-value: 7.112008068191216e-05, Skewness: -0.6099076344549264, Kurtosis: 4.826989405597512
# CNY is within the threshold for normal distribution.
# Figure(432x288)

# %%
# Box-Ljung Test of Autocorrelation in the ARIMA residuals + ACF, PACF plots.
for v in resultsdb.values():
    data = v[1]
    for col in COLS_EXCL_VIX:
        title = v[0] + " - " + col
        p,d,q = v[2][col][0]
        model = v[2][col][1]
        fitted = v[2][col][2]
        res = v[2][col][3]
        result = sm.stats.diagnostic.acorr_ljungbox(res, 
                                                    lags=range(5),
                                                    boxpierce=True, 
                                                    model_df=p+q, 
                                                    return_df=True)
        if result[(result["lb_pvalue"] < 0.01) &
                 (result["bp_pvalue"] < 0.01)].size > 0:
            print(title + ": ARIMA-fitted residuals exhibit autocorrelation.")
        else:
            print(title + ": No autocorrelation.")

        sm.graphics.tsa.plot_acf(data[col], lags=40, title=title + ": Autocorrelation")
        sm.graphics.tsa.plot_pacf(data[col], lags=40, title=title + ": Partial Autocorrelation")
# Out:
# Full Timeframe - SPX: No autocorrelation.
# Full Timeframe - SSE: No autocorrelation.
# Full Timeframe - CNY: No autocorrelation.
# COVID-19 Recession - SPX: No autocorrelation.
# COVID-19 Recession - SSE: No autocorrelation.
# COVID-19 Recession - CNY: No autocorrelation.

# %%
# Fit a GARCH(1,1) model for each asset using the ARIMA-fitted residuals.
# Forecast the assets' 95%, 99% Value at Risk for various timeranges.
from arch import arch_model

def buildGARCH(arima_pkg, asset, dataframe, date_cutoff=ALL_END, dist='normal', verbose=True):
    arima_res = pd.DataFrame({asset: arima_pkg[3]},
                              index=dataframe.index)
    am = arch_model(arima_res, mean='Zero', vol='Garch', p=1, o=0, q=1, dist=dist)
    res = am.fit(disp='off', last_obs=date_cutoff)
    if verbose:
        print(res.summary())
        fig = res.plot(annualize='D')
    return am, res

def VaR_parametric(asset, scope="ALL", 
                   train_end_date=ALL_END, forecast_start_date=ALL_START, 
                   start_date=ALL_START, end_date=ALL_END,
                   dist='skewt', verbose=True):
    arima_pkg = resultsdb[scope][2][asset]
    data = resultsdb[scope][1][asset].copy()
    len_diff = data.size - arima_pkg[3].size
    data = data[len_diff:]
    am, res = buildGARCH(arima_pkg, asset, data, date_cutoff=train_end_date, dist=dist, verbose=verbose)
    
    forecasts = res.forecast(start=forecast_start_date)
    cond_mean = forecasts.mean[forecast_start_date:]
    cond_var = forecasts.variance[forecast_start_date:]
    q = am.distribution.ppf([0.01,0.05], res.params[-2:])
    print(q)

    VaR = -cond_mean.values - np.sqrt(cond_var).values * q[None, :]
    VaR = pd.DataFrame(VaR, columns=["1%","5%"], index=cond_var.index)
    VaR = VaR[start_date:end_date]
    
    if len(resultsdb[scope]) == 3:
        resultsdb[scope].append({})

    ax = VaR.plot(legend=True)
    ax.plot(data, color="#BBBBBB")
    ax.set_title(col + ': Parametric VaR')
    print(ax)
    
    return VaR

# %%
# Parametrically-fitted VaR Series for the three assets in the Full Timeframe
# Great Recession time-period slice of Full-range VaR Series
# COVID-19 time-period slice of VaR forecast data based on training data from 2007-2018
# Graphs showing how closely fitted the VaR series are with historical asset returns.

GR_VaR = {}
CR_forecast_VaR = {}

for col in COLS_EXCL_VIX:
    resultsdb["ALL"][3][col] = VaR_parametric(col, scope="ALL", verbose=True)
    CR_forecast_VaR[col] = VaR_parametric(col, scope="ALL", 
                                          train_end_date=TRAIN_END, 
                                          forecast_start_date=FORECAST_START, 
                                          start_date=COVID_START, end_date=COVID_END, 
                                          verbose=False)
    GR_VaR[col] = VaR_parametric(col, scope="ALL", 
                                 start_date=GR_START, end_date=GR_END, 
                                 verbose=False)
# Out:
#                              Zero Mean - GARCH Model Results
# =========================================================================================
# Dep. Variable:                               SPX   R-squared:                       0.000
# Mean Model:                            Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:               -4215.94
# Distribution:      Standardized Skew Student's t   AIC:                           8441.89
# Method:                       Maximum Likelihood   BIC:                           8472.13
#                                                    No. Observations:                 3126
# Date:                           Sat, May 23 2020   Df Residuals:                     3121
# Time:                                   05:33:53   Df Model:                            5
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega          0.0170  4.689e-03      3.620  2.944e-04 [7.784e-03,2.616e-02]
# alpha[1]       0.1381  1.653e-02      8.350  6.840e-17     [  0.106,  0.170]
# beta[1]        0.8619  1.517e-02     56.833      0.000     [  0.832,  0.892]
#                               Distribution
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# nu             5.1420      0.456     11.269  1.871e-29 [  4.248,  6.036]
# lambda        -0.1593  1.982e-02     -8.037  9.209e-16 [ -0.198, -0.120]
# ========================================================================
#
# Covariance estimator: robust
# [-2.87047116 -1.66651082]
# AxesSubplot(0.125,0.2;0.775x0.68)
# [-2.84053341 -1.66428855]
# AxesSubplot(0.125,0.2;0.775x0.68)
# [-2.87047116 -1.66651082]
# AxesSubplot(0.125,0.2;0.775x0.68)
#                              Zero Mean - GARCH Model Results
# =========================================================================================
# Dep. Variable:                               SSE   R-squared:                       0.000
# Mean Model:                            Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:               -5375.57
# Distribution:      Standardized Skew Student's t   AIC:                           10761.1
# Method:                       Maximum Likelihood   BIC:                           10791.4
#                                                    No. Observations:                 3126
# Date:                           Sat, May 23 2020   Df Residuals:                     3121
# Time:                                   05:33:54   Df Model:                            5
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      7.2603e-03  3.312e-03      2.192  2.835e-02 [7.696e-04,1.375e-02]
# alpha[1]       0.0504  7.989e-03      6.306  2.866e-10 [3.472e-02,6.603e-02]
# beta[1]        0.9496  7.563e-03    125.570      0.000     [  0.935,  0.964]
#                                 Distribution
# ===========================================================================
#                  coef    std err          t      P>|t|     95.0% Conf. Int.
# ---------------------------------------------------------------------------
# nu             4.4693      0.360     12.405  2.465e-35    [  3.763,  5.175]
# lambda        -0.0792  1.801e-02     -4.397  1.098e-05 [ -0.115,-4.389e-02]
# ===========================================================================
#
# Covariance estimator: robust
# [-2.77902962 -1.59179588]
# AxesSubplot(0.125,0.2;0.775x0.68)
# [-2.77469168 -1.6019205 ]
# AxesSubplot(0.125,0.2;0.775x0.68)
# [-2.77902962 -1.59179588]
# AxesSubplot(0.125,0.2;0.775x0.68)
#                              Zero Mean - GARCH Model Results
# =========================================================================================
# Dep. Variable:                               CNY   R-squared:                       0.000
# Mean Model:                            Zero Mean   Adj. R-squared:                  0.000
# Vol Model:                                 GARCH   Log-Likelihood:                1444.80
# Distribution:      Standardized Skew Student's t   AIC:                          -2879.60
# Method:                       Maximum Likelihood   BIC:                          -2849.36
#                                                    No. Observations:                 3126
# Date:                           Sat, May 23 2020   Df Residuals:                     3121
# Time:                                   05:33:55   Df Model:                            5
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      8.4580e-04  8.424e-05     10.040  1.015e-23 [6.807e-04,1.011e-03]
# alpha[1]       0.0500  6.697e-03      7.466  8.265e-14 [3.687e-02,6.313e-02]
# beta[1]        0.9300  5.664e-03    164.201      0.000     [  0.919,  0.941]
#                                  Distribution
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# nu             4.1952      0.165     25.494 2.306e-143      [  3.873,  4.518]
# lambda         0.0000  1.462e-02      0.000      1.000 [-2.866e-02,2.866e-02]
# =============================================================================
#
# Covariance estimator: robust
#
# WARNING: The optimizer did not indicate successful convergence. The message was
# Positive directional derivative for linesearch. See convergence_flag.
# /home/majorlift/bin/miniconda3/envs/thicconda/lib/python3.7/site-packages/arch/univariate/base.py:605: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# [-2.64206002 -1.52172451]
# AxesSubplot(0.125,0.2;0.775x0.68)
# [-2.64362595 -1.51908519]
# /home/majorlift/bin/miniconda3/envs/thicconda/lib/python3.7/site-packages/arch/univariate/base.py:605: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# /home/majorlift/bin/miniconda3/envs/thicconda/lib/python3.7/site-packages/arch/univariate/base.py:605: ConvergenceWarning: The optimizer returned code 8. The message is:
# Positive directional derivative for linesearch
# See scipy.optimize.fmin_slsqp for code meaning.
#
#   ConvergenceWarning)
# AxesSubplot(0.125,0.2;0.775x0.68)
# [-2.64206002 -1.52172451]
# AxesSubplot(0.125,0.2;0.775x0.68)

# %%
# Granger Causality Implementation: Testing for Risk Spillover
from statsmodels.tsa.stattools import grangercausalitytests as granger_

def granger_bilateral(cause_data, effect_data, cause_title, effect_title, 
                      title, dateindex, confs=["5%","1%"], lag=20):
    if len(confs) > 0:
        results = {}
        data = (pd.DataFrame({cause_title: cause_data[conf],
                              effect_title: effect_data[conf]},
                             index=dateindex)
               for conf in confs)
        for dataframe, conf in zip(data, confs):
            forward = (granger_(dataframe[[effect_title, cause_title]], lag, verbose=False), 
                       (cause_title, effect_title), title, lag)
            backward = (granger_(dataframe[[cause_title, effect_title]], lag, verbose=False), 
                        (effect_title, cause_title), title, lag)
            results[conf] = (forward, backward)
        return results
    
    else:
        dataframe = pd.DataFrame({cause_title: cause_data,
                                  effect_title: effect_data},
                                 index=dateindex)
        forward = (granger_(dataframe[[effect_title, cause_title]], lag, verbose=False), 
                   (cause_title, effect_title), title, lag)
        backward = (granger_(dataframe[[cause_title, effect_title]], lag, verbose=False), 
                    (effect_title, cause_title), title, lag)
        return (forward, backward)
        
# Weak GC if p-value < alpha in >50% of lag entry F-tests
# Strong GC if >90%
# No GC if <50%
# Delayed effect if more than 3 out of the first 5 lags are non-significant or lag=1 is.
def print_granger(result, order, title, lag, conf, verbose=True):
    first_term = True
    yes_count = 0
    short_term = 0
    short_term_reject = ""
    
    header = title + ": \n" + order[0] + " -> " + order[1]
    causal_order = order[0] + " -> " + order[1]
    if verbose:
        print(header)
        print("Lag, Confidence Level, F-statistic, p-value, Granger-Causality")
    # Data
    for k,v in result.items():
        ftest = v[0]["params_ftest"]
        if ftest[1] < int(conf[0])*0.01:
            causality = "Yes"
            yes_count += 1
        else:
            causality = "No"
            if k == 1:
                first_term = False
            if k in range(1,6):
                short_term += 1
        if verbose:
            print(", ".join((str(k), conf, str(ftest[0]), str(ftest[1]), causality)))
    # Conclusion
    if yes_count >= lag / 2:
        if not first_term or short_term > 3:
            short_term_reject = "delayed"
        if yes_count >= lag * 0.9:
            if verbose:
                print("Strong Granger-Causality exists from " + order[0] + " to " + order[1] + " at conf=" + conf + ".")
            else:
                print(", ".join((causal_order, conf, "Strong", short_term_reject)))
        else:
            if verbose:
                print("Weak Granger-Causality exists from " + order[0] + " to " + order[1] + ".")
            else:
                print(", ".join((causal_order, conf, "Weak", short_term_reject)))
        if verbose and short_term_reject != "":
            print("But it is rejected in the short term.")
    else:
        if verbose:
            print("No Granger-Causality from " + order[0] + " to " + order[1] + ".")
        else:
            print(", ".join((causal_order, conf, "None")))
    if verbose:
        print()

# %%
# Bidirectional Granger Causality in 
# Implied Volatility (VIX) vs. Realized Volatility from Historical Data.

def RealVolAnnualized(timeseries):
    real_var = timeseries.rolling(21).var() * (252 / 21)
    return np.sqrt(real_var.dropna())

spx_real_vol = RealVolAnnualized(df_lret["SPX"].copy())
sns.relplot(kind="line", data=pd.DataFrame({"SPX Realized Volatility": spx_real_vol, 
                                            "VIX Returns": df["VIX"].copy()},
                                            index=spx_real_vol.index).dropna())

realvol_forward, realvol_backward = granger_bilateral(spx_real_vol, df["VIX"].copy(), 
                                        "SPX Realized Volatility (Rolling Window)", 
                                        "VIX Daily Quotes", 
                                         title="Implied vs. Realized Volatility",
                                         dateindex=spx_real_vol.index, 
                                         confs=[], lag=40)

print_granger(*realvol_forward, conf="5%", verbose=True)
print_granger(*realvol_backward, conf="5%", verbose=True)
# Out:
# Implied vs. Realized Volatility:
# SPX Realized Volatility (Rolling Window) -> VIX Daily Quotes
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 24.36829587360606, 8.376780865595236e-07, Yes
# 2, 5%, 2.7009439694860715, 0.0673001076912734, No
# 3, 5%, 1.3059024624766187, 0.27069385233580995, No
# 4, 5%, 1.4699643861241463, 0.2085883668982806, No
# 5, 5%, 0.6448726593099628, 0.66545799440954, No
# 6, 5%, 2.5179736001600603, 0.019637802234624267, Yes
# 7, 5%, 2.2226058614141286, 0.029756588743226644, Yes
# 8, 5%, 5.089394153457854, 2.5983024904153613e-06, Yes
# 9, 5%, 4.993771489332804, 1.0619260294716553e-06, Yes
# 10, 5%, 4.456360331424659, 2.9057411247828648e-06, Yes
# 11, 5%, 3.8245538542074256, 1.722318629862273e-05, Yes
# 12, 5%, 4.8983050226310185, 4.5632554687837134e-08, Yes
# 13, 5%, 4.7187361852546, 3.705047132457073e-08, Yes
# 14, 5%, 4.572146437319556, 2.8589436947672914e-08, Yes
# 15, 5%, 4.327698263415143, 4.3997478222031966e-08, Yes
# 16, 5%, 4.096907365324939, 7.349314586404613e-08, Yes
# 17, 5%, 3.824089779101045, 1.87690109264035e-07, Yes
# 18, 5%, 3.6417490881778627, 3.0760007415248597e-07, Yes
# 19, 5%, 4.266495351704287, 1.6993932515534908e-09, Yes
# 20, 5%, 4.311916275925711, 4.877429339596558e-10, Yes
# 21, 5%, 4.126896821246119, 8.744652118289925e-10, Yes
# 22, 5%, 4.057503017360418, 6.744042988131623e-10, Yes
# 23, 5%, 4.5778357811267645, 3.01002799828903e-12, Yes
# 24, 5%, 4.788814698426474, 1.54061153080564e-13, Yes
# 25, 5%, 4.828057433352962, 3.5918232403878567e-14, Yes
# 26, 5%, 4.657181720280855, 6.833688961957725e-14, Yes
# 27, 5%, 4.507984497205284, 1.1643018446140934e-13, Yes
# 28, 5%, 4.653363567125487, 9.30337374496157e-15, Yes
# 29, 5%, 4.568514235400197, 8.695946921263545e-15, Yes
# 30, 5%, 4.47196721956871, 9.862205771458145e-15, Yes
# 31, 5%, 4.3094020178056995, 2.5869983043303542e-14, Yes
# 32, 5%, 4.170254783883411, 5.674365245262003e-14, Yes
# 33, 5%, 4.126809028824605, 4.209377295089572e-14, Yes
# 34, 5%, 4.1211215176272065, 2.0019186182203188e-14, Yes
# 35, 5%, 4.347663501243697, 4.651211693708007e-16, Yes
# 36, 5%, 4.158661908141536, 2.404247217070431e-15, Yes
# 37, 5%, 4.080540362712035, 3.071305205946014e-15, Yes
# 38, 5%, 4.234097272331656, 1.6212002175725327e-16, Yes
# 39, 5%, 4.170060793218515, 1.7541875850771032e-16, Yes
# 40, 5%, 4.0706735911909435, 3.3208658321806326e-16, Yes
# Strong Granger-Causality exists from SPX Realized Volatility (Rolling Window) to VIX Daily Quotes at conf=5%.
# But it is rejected in the short term.
#
# Implied vs. Realized Volatility:
# VIX Daily Quotes -> SPX Realized Volatility (Rolling Window)
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 298.4629231039453, 6.35311492636268e-64, Yes
# 2, 5%, 129.93887626175888, 6.4452164212190616e-55, Yes
# 3, 5%, 80.12940369969735, 6.385608850422787e-50, Yes
# 4, 5%, 60.1645035436855, 5.324357325228141e-49, Yes
# 5, 5%, 48.64093031157887, 1.3298149817918351e-48, Yes
# 6, 5%, 43.41249397846487, 3.660110374298361e-51, Yes
# 7, 5%, 40.025736285863964, 3.348221007252819e-54, Yes
# 8, 5%, 39.68209419044631, 1.2445666227367714e-60, Yes
# 9, 5%, 37.4575310781325, 1.3008951028688191e-63, Yes
# 10, 5%, 34.68443652086218, 1.0940312915544793e-64, Yes
# 11, 5%, 32.74436432902965, 1.8587782093287581e-66, Yes
# 12, 5%, 31.987389748349283, 3.615014319784382e-70, Yes
# 13, 5%, 29.68483892546842, 8.22328844881284e-70, Yes
# 14, 5%, 27.69720893559809, 1.962872240805621e-69, Yes
# 15, 5%, 25.96870827701195, 4.705240603586844e-69, Yes
# 16, 5%, 24.061177214769117, 1.633622342590591e-67, Yes
# 17, 5%, 25.129206490367878, 1.2494193015714983e-74, Yes
# 18, 5%, 25.04302294328365, 2.938685380996399e-78, Yes
# 19, 5%, 25.41442558991361, 2.11605975769774e-83, Yes
# 20, 5%, 24.531806752537165, 4.0785289858751324e-84, Yes
# 21, 5%, 28.483298026450363, 1.4890466734197974e-102, Yes
# 22, 5%, 22.345683338536464, 6.0111171716300184e-83, Yes
# 23, 5%, 20.936341375253924, 1.731293270316029e-80, Yes
# 24, 5%, 19.203637490889076, 3.8101401450162526e-76, Yes
# 25, 5%, 18.602539325587205, 2.863479920327378e-76, Yes
# 26, 5%, 17.641829108694516, 1.631571355488724e-74, Yes
# 27, 5%, 16.89923200666613, 1.7672955474535472e-73, Yes
# 28, 5%, 16.068427680730643, 9.464804987809589e-72, Yes
# 29, 5%, 15.419828323409977, 1.117560372224388e-70, Yes
# 30, 5%, 14.902604962613184, 4.380267547109611e-70, Yes
# 31, 5%, 14.449067893106088, 1.1506710552651045e-69, Yes
# 32, 5%, 13.9992862818606, 4.0999857102411073e-69, Yes
# 33, 5%, 13.505014704472426, 3.753482951642289e-68, Yes
# 34, 5%, 13.11260953822314, 1.2381333723271116e-67, Yes
# 35, 5%, 12.783645568064168, 2.2557064270577036e-67, Yes
# 36, 5%, 12.388176084765004, 1.3868118241574132e-66, Yes
# 37, 5%, 12.048777079920768, 5.007599285393793e-66, Yes
# 38, 5%, 11.838795977890896, 3.269120698542394e-66, Yes
# 39, 5%, 11.622684145109986, 2.763364545331146e-66, Yes
# 40, 5%, 12.071154705817369, 7.1472149066374675e-71, Yes
# Strong Granger-Causality exists from VIX Daily Quotes to SPX Realized Volatility (Rolling Window) at conf=5%.

# %%
# Bidirectional Granger Causality of VaRs between SPX and SSE/CNY
# Full Timeframe, Great Recession, COVID-19 Recession compared.

VaRs = resultsdb["ALL"][0], resultsdb["ALL"][3], ["5%","1%"]
GR_VaRs = "Great Recession", GR_VaR, ["5%","1%"]
CR_VaRs = "COVID-19 Recession", CR_forecast_VaR, ["5%","1%"]

def print_grangers(VaR_datasets, verbose=False):
    for timeframe, VaR_df, confs in VaR_datasets:
        if not verbose:
            print("\n" + timeframe + ": \n")
        for CHN in ("SSE","CNY"):
            results = granger_bilateral(VaR_df["SPX"], VaR_df[CHN], 
                                       "SPX", CHN,
                                        title=timeframe, 
                                        dateindex=VaR_df["SPX"].index,
                                        lag=10,
                                        confs=confs)
            for k, v in results.items():
                print_granger(*v[0], conf=k, verbose=verbose)
                print_granger(*v[1], conf=k, verbose=verbose)
            
print_grangers((VaRs, GR_VaRs, CR_VaRs), verbose=False)
print()
print_grangers((VaRs, GR_VaRs, CR_VaRs), verbose=True)
# Out:
# Full Timeframe:
#
# SPX -> SSE, 5%, Strong, delayed
# SSE -> SPX, 5%, Strong,
# SPX -> SSE, 1%, Weak, delayed
# SSE -> SPX, 1%, Weak,
# SPX -> CNY, 5%, Strong, delayed
# CNY -> SPX, 5%, None
# SPX -> CNY, 1%, Weak, delayed
# CNY -> SPX, 1%, None
#
# Great Recession:
#
# SPX -> SSE, 5%, None
# SSE -> SPX, 5%, None
# SPX -> SSE, 1%, None
# SSE -> SPX, 1%, None
# SPX -> CNY, 5%, None
# CNY -> SPX, 5%, None
# SPX -> CNY, 1%, None
# CNY -> SPX, 1%, None
#
# COVID-19 Recession:
#
# SPX -> SSE, 5%, None
# SSE -> SPX, 5%, None
# SPX -> SSE, 1%, None
# SSE -> SPX, 1%, None
# SPX -> CNY, 5%, Strong, delayed
# CNY -> SPX, 5%, None
# SPX -> CNY, 1%, None
# CNY -> SPX, 1%, None
#
# Full Timeframe:
# SPX -> SSE
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.021847421778346723, 0.882503261407205, No
# 2, 5%, 3.554865813474542, 0.028701085970757764, Yes
# 3, 5%, 5.822405144542828, 0.0005788632829249195, Yes
# 4, 5%, 4.308501095459372, 0.0017737662340705242, Yes
# 5, 5%, 3.694984202259988, 0.002453980573913133, Yes
# 6, 5%, 3.429628347373445, 0.0022337756662623555, Yes
# 7, 5%, 2.9659727190416083, 0.004225031693973738, Yes
# 8, 5%, 2.5790761386945684, 0.00833809856918168, Yes
# 9, 5%, 2.6015063893988586, 0.005452644835583764, Yes
# 10, 5%, 2.417515971692195, 0.007307764424763815, Yes
# Strong Granger-Causality exists from SPX to SSE at conf=5%.
# But it is rejected in the short term.
#
# Full Timeframe:
# SSE -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 7.7944693556756155, 0.005272528156896206, Yes
# 2, 5%, 6.1893518875035625, 0.0020764364042751087, Yes
# 3, 5%, 4.109152450947259, 0.006407822071564728, Yes
# 4, 5%, 3.146321289139116, 0.013615162238432371, Yes
# 5, 5%, 2.8959415978387044, 0.012973698379000434, Yes
# 6, 5%, 2.837124271780732, 0.009330389381655906, Yes
# 7, 5%, 3.7527255594465765, 0.0004677721212625486, Yes
# 8, 5%, 3.2259122431561718, 0.0011701746243528931, Yes
# 9, 5%, 2.874075151000713, 0.002212337469327378, Yes
# 10, 5%, 2.617606479158128, 0.003608454131154772, Yes
# Strong Granger-Causality exists from SSE to SPX at conf=5%.
#
# Full Timeframe:
# SPX -> SSE
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.02184742177847936, 0.8825032614062798, No
# 2, 1%, 3.5548658134745814, 0.028701085970757764, No
# 3, 1%, 5.822405144543004, 0.0005788632829247231, Yes
# 4, 1%, 4.308501095459352, 0.0017737662340705242, Yes
# 5, 1%, 3.6949842022602333, 0.002453980573911662, Yes
# 6, 1%, 3.42962834737353, 0.0022337756662613416, Yes
# 7, 1%, 2.965972719041576, 0.004225031693973738, Yes
# 8, 1%, 2.5790761386942074, 0.008338098569190886, Yes
# 9, 1%, 2.601506389398397, 0.0054526448355915955, Yes
# 10, 1%, 2.4175159716921706, 0.007307764424763815, Yes
# Weak Granger-Causality exists from SPX to SSE.
# But it is rejected in the short term.
#
# Full Timeframe:
# SSE -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 7.794469355676027, 0.00527252815689476, Yes
# 2, 1%, 6.189351887503403, 0.0020764364042755216, Yes
# 3, 1%, 4.109152450947128, 0.00640782207156569, Yes
# 4, 1%, 3.1463212891394394, 0.013615162238426579, No
# 5, 1%, 2.895941597838695, 0.012973698379000434, No
# 6, 1%, 2.8371242717808536, 0.009330389381651878, Yes
# 7, 1%, 3.752725559446702, 0.0004677721212623733, Yes
# 8, 1%, 3.225912243155891, 0.0011701746243538782, Yes
# 9, 1%, 2.8740751510011204, 0.0022123374693244703, Yes
# 10, 1%, 2.6176064791580487, 0.0036084541311560666, Yes
# Weak Granger-Causality exists from SSE to SPX.
#
# Full Timeframe:
# SPX -> CNY
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.007404109663086197, 0.931434464559694, No
# 2, 5%, 5.371118608690991, 0.004692028004149575, Yes
# 3, 5%, 3.702962323432571, 0.01124431019591186, Yes
# 4, 5%, 2.752537393967436, 0.02662866925236379, Yes
# 5, 5%, 5.450011674400412, 5.346410893652924e-05, Yes
# 6, 5%, 4.566043625331459, 0.00012756221209663887, Yes
# 7, 5%, 4.022190030579855, 0.00021526604223064306, Yes
# 8, 5%, 3.5922935592278846, 0.0003676161526142547, Yes
# 9, 5%, 3.2152772758832144, 0.0006907095933913869, Yes
# 10, 5%, 3.040776314692299, 0.0007654472651397235, Yes
# Strong Granger-Causality exists from SPX to CNY at conf=5%.
# But it is rejected in the short term.
#
# Full Timeframe:
# CNY -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.042798963261585214, 0.8361177681254791, No
# 2, 5%, 0.317148932922031, 0.728245772134188, No
# 3, 5%, 0.18003271697728254, 0.9099888096534777, No
# 4, 5%, 0.844743231776071, 0.4966343264718799, No
# 5, 5%, 0.7214660931333887, 0.6072658287240691, No
# 6, 5%, 0.7235807940084947, 0.6306010441063025, No
# 7, 5%, 1.3569112804107173, 0.21926579007270502, No
# 8, 5%, 1.5164126242346025, 0.14595813547275863, No
# 9, 5%, 1.7123756982175165, 0.08075231729881488, No
# 10, 5%, 1.6756071114754936, 0.08049765810782802, No
# No Granger-Causality from CNY to SPX.
#
# Full Timeframe:
# SPX -> CNY
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.00740410966310745, 0.931434464559694, No
# 2, 1%, 5.371118608690775, 0.004692028004150179, Yes
# 3, 1%, 3.7029623234334443, 0.011244310195896562, No
# 4, 1%, 2.752537393967462, 0.02662866925236379, No
# 5, 1%, 5.450011674401219, 5.346410893643028e-05, Yes
# 6, 1%, 4.5660436253316945, 0.00012756221209656317, Yes
# 7, 1%, 4.022190030576247, 0.0002152660422329003, Yes
# 8, 1%, 3.5922935592254874, 0.0003676161526170849, Yes
# 9, 1%, 3.2152772758818586, 0.0006907095933946353, Yes
# 10, 1%, 3.0407763146907336, 0.0007654472651442364, Yes
# Weak Granger-Causality exists from SPX to CNY.
# But it is rejected in the short term.
#
# Full Timeframe:
# CNY -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.04279896326159704, 0.8361177681254791, No
# 2, 1%, 0.3171489329220421, 0.728245772134188, No
# 3, 1%, 0.18003271697729104, 0.9099888096534777, No
# 4, 1%, 0.8447432317760515, 0.4966343264718799, No
# 5, 1%, 0.7214660931333869, 0.6072658287240691, No
# 6, 1%, 0.7235807940084983, 0.6306010441063025, No
# 7, 1%, 1.3569112804107273, 0.21926579007270502, No
# 8, 1%, 1.5164126242345888, 0.14595813547275863, No
# 9, 1%, 1.7123756982175395, 0.08075231729881488, No
# 10, 1%, 1.6756071114754811, 0.08049765810782802, No
# No Granger-Causality from CNY to SPX.
#
# Great Recession:
# SPX -> SSE
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.006477523312467091, 0.9358968176365315, No
# 2, 5%, 0.03744291918647316, 0.9632530985720049, No
# 3, 5%, 1.1155421771278526, 0.34268489204585295, No
# 4, 5%, 0.8922813120977329, 0.4686083137983672, No
# 5, 5%, 0.7447615656712427, 0.590385072872142, No
# 6, 5%, 0.6475591412305827, 0.6921058048434428, No
# 7, 5%, 0.6606306338952861, 0.7053946495680483, No
# 8, 5%, 0.644031894196238, 0.7405158374302763, No
# 9, 5%, 0.8581783909292331, 0.5630474898868127, No
# 10, 5%, 0.7702001278062905, 0.6576051137351346, No
# No Granger-Causality from SPX to SSE.
#
# Great Recession:
# SSE -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 1.4198274742398163, 0.2341997028807809, No
# 2, 5%, 1.1883921072353398, 0.3058869854387469, No
# 3, 5%, 0.9042082605988929, 0.43916825812738813, No
# 4, 5%, 0.9764746032889376, 0.42031923487321454, No
# 5, 5%, 0.8935871642019263, 0.48541612203942874, No
# 6, 5%, 0.902581878061597, 0.49304597244010484, No
# 7, 5%, 1.788747767409672, 0.08844427101057911, No
# 8, 5%, 1.5932202402793183, 0.1254242270708926, No
# 9, 5%, 1.3911433985654393, 0.19053780111259952, No
# 10, 5%, 1.184654513608004, 0.29996476873883493, No
# No Granger-Causality from SSE to SPX.
#
# Great Recession:
# SPX -> SSE
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.006477523312463932, 0.9358968176365315, No
# 2, 1%, 0.03744291918647179, 0.9632530985720049, No
# 3, 1%, 1.1155421771278493, 0.34268489204585295, No
# 4, 1%, 0.8922813120977195, 0.46860831379837276, No
# 5, 1%, 0.7447615656712548, 0.5903850728721365, No
# 6, 1%, 0.6475591412305924, 0.6921058048434321, No
# 7, 1%, 0.6606306338952985, 0.7053946495680345, No
# 8, 1%, 0.6440318941962258, 0.7405158374302884, No
# 9, 1%, 0.8581783909292546, 0.5630474898867961, No
# 10, 1%, 0.770200127806287, 0.6576051137351346, No
# No Granger-Causality from SPX to SSE.
#
# Great Recession:
# SSE -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 1.4198274742398225, 0.2341997028807809, No
# 2, 1%, 1.1883921072353811, 0.3058869854387299, No
# 3, 1%, 0.904208260598912, 0.4391682581273809, No
# 4, 1%, 0.9764746032889355, 0.42031923487321454, No
# 5, 1%, 0.8935871642020595, 0.4854161220393365, No
# 6, 1%, 0.9025818780615817, 0.4930459724401196, No
# 7, 1%, 1.7887477674096914, 0.08844427101057596, No
# 8, 1%, 1.5932202402793283, 0.1254242270708878, No
# 9, 1%, 1.3911433985654342, 0.19053780111260252, No
# 10, 1%, 1.184654513608003, 0.2999647687388476, No
# No Granger-Causality from SSE to SPX.
# Great Recession:
# SPX -> CNY
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.17110619920061299, 0.679371513896948, No
# 2, 5%, 0.08836705362035364, 0.9154443833629399, No
# 3, 5%, 0.1417445736469102, 0.934911035216364, No
# 4, 5%, 0.25678454418770236, 0.9054404182463326, No
# 5, 5%, 0.7747185677520589, 0.5684469741477916, No
# 6, 5%, 0.6562649865282498, 0.6850781249456299, No
# 7, 5%, 0.9207717979089054, 0.4902807241684015, No
# 8, 5%, 1.0342364363546492, 0.4097054090534165, No
# 9, 5%, 1.014746521966741, 0.4276517707890033, No
# 10, 5%, 0.8768304951291166, 0.5551647149382488, No
# No Granger-Causality from SPX to CNY.
#
# Great Recession:
# CNY -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.07677399297402038, 0.7818733284728023, No
# 2, 5%, 1.5537238198133903, 0.212854325881246, No
# 3, 5%, 1.2206345401409249, 0.30200319561744404, No
# 4, 5%, 1.0353053553274694, 0.38883417074924387, No
# 5, 5%, 1.2910073215240174, 0.2671119339535277, No
# 6, 5%, 1.0865655630897926, 0.3699355736016913, No
# 7, 5%, 0.9871006890501633, 0.4403087170733406, No
# 8, 5%, 0.994979155294484, 0.4395833577270414, No
# 9, 5%, 0.849793896788944, 0.5706913625249761, No
# 10, 5%, 0.9411414321355277, 0.495328380691207, No
# No Granger-Causality from CNY to SPX.
#
# Great Recession:
# SPX -> CNY
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.17110619920060988, 0.679371513896948, No
# 2, 1%, 0.08836705361787736, 0.9154443833652038, No
# 3, 1%, 0.14174457364633383, 0.9349110352167369, No
# 4, 1%, 0.256784544187503, 0.9054404182464558, No
# 5, 1%, 0.7747185677519169, 0.5684469741478979, No
# 6, 1%, 0.6562649865296585, 0.6850781249444986, No
# 7, 1%, 0.9207717979095155, 0.49028072416792834, No
# 8, 1%, 1.034236436355116, 0.40970540905306657, No
# 9, 1%, 1.014746521966578, 0.42765177078913585, No
# 10, 1%, 0.8768304951297136, 0.555164714937683, No
# No Granger-Causality from SPX to CNY.
#
# Great Recession:
# CNY -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.076773992974015, 0.7818733284728023, No
# 2, 1%, 1.5537238198134309, 0.21285432588123765, No
# 3, 1%, 1.2206345401409138, 0.30200319561745376, No
# 4, 1%, 1.0353053553274554, 0.3888341707492454, No
# 5, 1%, 1.2910073215240172, 0.2671119339535277, No
# 6, 1%, 1.0865655630898152, 0.36993557360167556, No
# 7, 1%, 0.9871006890501773, 0.4403087170733313, No
# 8, 1%, 0.994979155294474, 0.4395833577270488, No
# 9, 1%, 0.8497938967889584, 0.5706913625249652, No
# 10, 1%, 0.9411414321355227, 0.4953283806912102, No
# No Granger-Causality from CNY to SPX.
#
# COVID-19 Recession:
# SPX -> SSE
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.015884015294484768, 0.8999817692180105, No
# 2, 5%, 0.025191973648224113, 0.9751296469417063, No
# 3, 5%, 0.12249788297445709, 0.9466031326602677, No
# 4, 5%, 0.09603695435488173, 0.9834595261577471, No
# 5, 5%, 0.13395727911155236, 0.9840797685366691, No
# 6, 5%, 0.4358143548213314, 0.8527720712132807, No
# 7, 5%, 0.3800916713009316, 0.9112080147893075, No
# 8, 5%, 0.36830882767411327, 0.9339068153408828, No
# 9, 5%, 0.3196409782418892, 0.9658503656131835, No
# 10, 5%, 0.2897413478261196, 0.9812831833436895, No
# No Granger-Causality from SPX to SSE.
#
# COVID-19 Recession:
# SSE -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 2.624314948101976, 0.1086608314256975, No
# 2, 5%, 1.085247872603393, 0.34224587306377713, No
# 3, 5%, 0.7781209462554409, 0.5093597663533784, No
# 4, 5%, 0.7365955161062478, 0.5696300233559546, No
# 5, 5%, 0.65452223241748, 0.658904803914193, No
# 6, 5%, 0.49017860779699834, 0.8138009393320852, No
# 7, 5%, 0.3897582372090665, 0.9055545343627065, No
# 8, 5%, 0.5305371273855034, 0.8297049713194572, No
# 9, 5%, 0.6161428504687403, 0.7792037632719282, No
# 10, 5%, 0.5315052994259418, 0.8616638547315986, No
# No Granger-Causality from SSE to SPX.
#
# COVID-19 Recession:
# SPX -> SSE
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.015884015294489868, 0.8999817692180105, No
# 2, 1%, 0.025191973648214926, 0.9751296469417208, No
# 3, 1%, 0.12249788297446738, 0.946603132660262, No
# 4, 1%, 0.09603695435489347, 0.9834595261577433, No
# 5, 1%, 0.13395727911154984, 0.9840797685366697, No
# 6, 1%, 0.4358143548213682, 0.8527720712132564, No
# 7, 1%, 0.3800916713009757, 0.911208014789282, No
# 8, 1%, 0.36830882767411194, 0.9339068153408838, No
# 9, 1%, 0.31964097824188514, 0.9658503656131852, No
# 10, 1%, 0.2897413478261045, 0.9812831833436932, No
# No Granger-Causality from SPX to SSE.
#
# COVID-19 Recession:
# SSE -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 2.624314948101965, 0.10866083142569936, No
# 2, 1%, 1.085247872603388, 0.34224587306377713, No
# 3, 1%, 0.7781209462554388, 0.5093597663533818, No
# 4, 1%, 0.7365955161062536, 0.5696300233559513, No
# 5, 1%, 0.6545222324174781, 0.658904803914196, No
# 6, 1%, 0.4901786077969817, 0.8138009393320977, No
# 7, 1%, 0.3897582372090657, 0.9055545343627079, No
# 8, 1%, 0.5305371273855088, 0.829704971319453, No
# 9, 1%, 0.6161428504687312, 0.7792037632719366, No
# 10, 1%, 0.5315052994259466, 0.8616638547315955, No
# No Granger-Causality from SSE to SPX.
#
# COVID-19 Recession:
# SPX -> CNY
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 2.542765276599913, 0.11423039147633007, No
# 2, 5%, 4.316247455269852, 0.016251934145145974, Yes
# 3, 5%, 3.1762559183243937, 0.028134281624888163, Yes
# 4, 5%, 2.6328742803227048, 0.03988307331100667, Yes
# 5, 5%, 4.314146891607072, 0.0015864815281476613, Yes
# 6, 5%, 3.421826132627828, 0.004779064108148069, Yes
# 7, 5%, 2.8011160370509565, 0.01213364591127682, Yes
# 8, 5%, 2.421939282792654, 0.022513810212731564, Yes
# 9, 5%, 2.1995490472275976, 0.032507432394819145, Yes
# 10, 5%, 2.2886750821476287, 0.02277921360022807, Yes
# Strong Granger-Causality exists from SPX to CNY at conf=5%.
# But it is rejected in the short term.
#
# COVID-19 Recession:
# CNY -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 5%, 0.1444853872115202, 0.7047381605668265, No
# 2, 5%, 1.1566997663344647, 0.3192048868176528, No
# 3, 5%, 0.3081198262101782, 0.8194532336357901, No
# 4, 5%, 0.5641461720402317, 0.6893279237005151, No
# 5, 5%, 0.6835421175425122, 0.6372294288294209, No
# 6, 5%, 0.7269397279591865, 0.6292442565685816, No
# 7, 5%, 0.7476868748997197, 0.6325012736147644, No
# 8, 5%, 0.6283021881223743, 0.7513387202188752, No
# 9, 5%, 0.657686029356753, 0.7437218021036418, No
# 10, 5%, 0.645916827065824, 0.769080929882328, No
# No Granger-Causality from CNY to SPX.
#
# COVID-19 Recession:
# SPX -> CNY
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 2.54276527659995, 0.11423039147632737, No
# 2, 1%, 4.316247455269999, 0.01625193414514377, No
# 3, 1%, 3.176255918327835, 0.028134281624768723, No
# 4, 1%, 2.6328742803234846, 0.039883073310959805, No
# 5, 1%, 4.314146891607203, 0.0015864815281473085, Yes
# 6, 1%, 3.42182613262804, 0.004779064108146079, Yes
# 7, 1%, 2.8011160370509396, 0.012133645911277212, No
# 8, 1%, 2.421939282792516, 0.022513810212738662, No
# 9, 1%, 2.1995490472271815, 0.03250743239485214, No
# 10, 1%, 2.2886750821474076, 0.022779213600241054, No
# No Granger-Causality from SPX to CNY.
#
# COVID-19 Recession:
# CNY -> SPX
# Lag, Confidence Level, F-statistic, p-value, Granger-Causality
# 1, 1%, 0.14448538721152152, 0.7047381605668265, No
# 2, 1%, 1.1566997663344625, 0.3192048868176528, No
# 3, 1%, 0.3081198262101819, 0.8194532336357878, No
# 4, 1%, 0.5641461720402354, 0.6893279237005134, No
# 5, 1%, 0.6835421175425134, 0.6372294288294209, No
# 6, 1%, 0.7269397279591877, 0.6292442565685816, No
# 7, 1%, 0.7476868748997213, 0.6325012736147619, No
# 8, 1%, 0.6283021881223787, 0.7513387202188706, No
# 9, 1%, 0.6576860293567516, 0.7437218021036437, No
# 10, 1%, 0.6459168270658205, 0.7690809298823301, No
# No Granger-Causality from CNY to SPX.
